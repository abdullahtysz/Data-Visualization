# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
df= pd.read_csv("PoliceKillingsUS.csv",encoding="windows-1252")

# %%
df.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
df.manner_of_death.value_counts().index
# Out:
# Index(['shot', 'shot and Tasered'], dtype='object')

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x = "gender", y = 'age', data = df,hue="manner_of_death")
plt.legend(loc = (0.64, 0.85));

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
plt.figure(figsize=(10,6))
ax = sns.swarmplot(x="gender", y="age", hue="manner_of_death", data=df);

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
df.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
df.city.value_counts().head(12)
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Indianapolis     14
# Name: city, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = df.city.value_counts()[:13].index, y = df.city.value_counts()[:13].values)
plt.title('Most dangerous cities', color = "blue")
plt.xticks(rotation = 45);

# %%
# with seaborn countplot

# %%
plt.figure(figsize=(8,4))
sns.countplot(data = df , x = "city", order = df.city.value_counts()[:13].index);

plt.title('Most dangerous cities', color = "green")
plt.xticks(rotation = 45)
for index, value in enumerate(df.city.value_counts()[:13]):
  plt.text(index,value +0.71,str(value), ha = "center" )

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
df.state.value_counts().head(21)
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# WA     62
# IL     62
# TN     59
# LA     57
# NM     51
# PA     51
# AL     50
# VA     47
# NY     45
# SC     44
# KY     43
# Name: state, dtype: int64

# %%
# with seaborn barplot

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = df.state.value_counts().head(21).index, y = df.state.value_counts().head(21).values,data= df)
plt.title("Most Dangerous States", color = "blue")
plt.xticks(rotation = 45);

# %%
# with seaborn countplot
sns.countplot(x = "signs_of_mental_illness", order = df.signs_of_mental_illness.value_counts().index, data =df)

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
df.head()
# Out:
#    id                name  ... 12 most dangerous cities            new
# 0   3          Tim Elliot  ...                      NaN        Shelton
# 1   4    Lewis Lee Lembke  ...                      NaN          Aloha
# 2   5  John Paul Quintero  ...                      NaN        Wichita
# 3   8     Matthew Hoffman  ...                      NaN  San Francisco
# 4   9   Michael Rodriguez  ...                      NaN          Evans
#
# [5 rows x 16 columns]

# %%
df.signs_of_mental_illness.value_counts()
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x = "signs_of_mental_illness", order = df.signs_of_mental_illness.value_counts().index, data =df)
for index, value in enumerate(df.signs_of_mental_illness.value_counts()):
  plt.text(index,value ,str(value), ha = "center" )

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
df.threat_level.value_counts()
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
sns.countplot(x = "threat_level", order = df.threat_level.value_counts().index, data = df);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
df.flee.value_counts()
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
sns.countplot(x = "flee", order = df.flee.value_counts().index, data = df);
